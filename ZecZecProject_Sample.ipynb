# %% [markdown]
# ## Main

# %%
from seleniumbase import SB
import pandas as pd

# %%
def verify_success(sb):
    sb.assert_element('img[alt="Logo Assembly"]', timeout=8)
    sb.sleep(4)

def scroll_down(sb):
    # sb.execute_script('window.scrollTo({top: document.body.scrollHeight, behavior: "smooth"});')
    current_scroll_position, new_height= 0, 1
    while current_scroll_position <= new_height:
        current_scroll_position += 100
        sb.execute_script("window.scrollTo(0, {});".format(current_scroll_position))
        new_height = sb.execute_script("return document.body.scrollHeight")
    sb.sleep(5)

def zeczec_crawler(url):
    project_id = url.split("/")[-1]
    print(f'---- Start to collect {project_id} ----')

    with SB(uc_cdp=True, guest_mode=True) as sb:

        project = {'id': project_id}
        sb.open(url)

        if sb.is_element_visible('.js-expand-project-content'):
            # ------- basic info -------
            title = sb.find_element('h1.text-lg.tracking-wide')
            # print(title.text)

            cate = sb.find_element('a[href^="/categories?category"]')
            # print(cate.text)

            duration = sb.find_element('h3.inline-block.text-gray-500.text-xs')
            # print(duration.text)

            desc = sb.find_element('p.text-gray-500.text-sm.tracking-wider')
            # print(desc.text)

            project['title'] = title.text
            project['category'] = cate.text
            project['duration'] = duration.text
            project['desc'] = desc.text

            print('collected [basic info]')

            # ------- content -------
            elements = sb.find_elements('.js-expand-project-content')
            for element in elements:
                project_text = element.text
                
            # print(project_text)
            project['text'] = project_text

            print('collected [project content]')

            # ------- highlight content -------
            color_text = []
            elements = sb.find_elements('.js-expand-project-content span[class*="color"]')
            for element in elements:
                # print(element.text)
                if element.text:
                    color_text.append(element.text)
            
            project['color_text'] = color_text

            bold_text = []
            # elements = sb.find_elements('.js-expand-project-content span b')
            elements = sb.find_elements('.js-expand-project-content b')
            for element in elements:
                # print(element.text)
                if element.text:
                    bold_text.append(element.text)

            project['bold_text'] = bold_text

            hyper_text = []
            # elements = sb.find_elements('.js-expand-project-content span a')
            elements = sb.find_elements('.js-expand-project-content a')
            for element in elements:
                # print(element.text)
                if element.text:
                    hyper_text.append(element.text) 

            project['hyper_text'] = hyper_text

            print('collected [project highlight content]')

            # ------- img -------
            scroll_down(sb)

            project_img = []
            elements = sb.find_elements('.js-expand-project-content img')
            for e in elements:
                src = e.get_attribute('data-src')
                if src:
                    project_img.append(src)
                # print(src)
            
            project['img_list'] = project_img

            print('collected [project img]')

            sb.sleep(5) # wait

        else:
            print(False)
            try:
                verify_success(sb)
            except Exception:
                print("Detected!")
    
    print(f'---- Complete to collect {project_id} ----')
    return project

# %% [markdown]
# ## Loop

# %%
## --- Init Setting --- ## 

collected_data = []

start_idx = 10001
end_idx = start_idx + 1000
file_name = f'ProjectData_{start_idx}-{end_idx-1}.csv'
print(file_name)

project_list = pd.read_csv('./ProjectList.csv')
project_list[start_idx: end_idx]
# Out:
# ProjectData_10001-11000.csv
#                                               cover_text  \
# 10001  Travel with Ü - 收藏你旅行的回憶與微笑\n102%\nNT$ 102,400...
# 10002    食農繪本出版計劃\n111%\nNT$ 55,750\nperson\n33\n人\n集資成功
# 10003  《HT.Chen白日夢遊先生》醫學系休學生影像日記\n152%\nNT$ 76,190\np...
# 10004  EZPLUG™ 最小的智慧溫控插頭 - 舒肥烹調好幫手\n100%\nNT$ 1,004,5...
# 10005  SUSTAIN 地表最強發熱背心-超機能，多季節穿搭，輕薄保暖\n240%\nNT$ 720...
# ...                                                  ...
# 10996  Stagg EKG600 | 溫控手沖壼 | 畫出生活與設計間最完美的水流\n1,242%\...
# 10997  Travel with Ü - 收藏你旅行的回憶與微笑\n102%\nNT$ 102,400...
# 10998    食農繪本出版計劃\n111%\nNT$ 55,750\nperson\n33\n人\n集資成功
# 10999  《HT.Chen白日夢遊先生》醫學系休學生影像日記\n152%\nNT$ 76,190\np...
# 11000  EZPLUG™ 最小的智慧溫控插頭 - 舒肥烹調好幫手\n100%\nNT$ 1,004,5...
#
#                                                      url  \
# 10001      https://www.zeczec.com/projects/travel-with-u
# 10002  https://www.zeczec.com/projects/shi-nong-hui-b...
# 10003            https://www.zeczec.com/projects/ht-chen
# 10004             https://www.zeczec.com/projects/ezplug
# 10005  https://www.zeczec.com/projects/sustain-heated...
# ...                                                  ...
# 10996        https://www.zeczec.com/projects/staggekg600
# 10997      https://www.zeczec.com/projects/travel-with-u
# 10998  https://www.zeczec.com/projects/shi-nong-hui-b...
# 10999            https://www.zeczec.com/projects/ht-chen
# 11000             https://www.zeczec.com/projects/ezplug
#
#                                     id
# 10001                    travel-with-u
# 10002  shi-nong-hui-ben-chu-ban-ji-hua
# 10003                          ht-chen
# 10004                           ezplug
# 10005              sustain-heated-vest
# ...                                ...
# 10996                      staggekg600
# 10997                    travel-with-u
# 10998  shi-nong-hui-ben-chu-ban-ji-hua
# 10999                          ht-chen
# 11000                           ezplug
#
# [1000 rows x 3 columns]

# %%
## --- Running --- ## 
error_log = {}

for i in range(start_idx, end_idx):
    project_url = project_list.iloc[i]['url']
    print(f'{i}: {project_url}')
    try:
        data = zeczec_crawler(project_url)
    except Exception as err:
        error_log[project_url] = err
        print(f'Collect Error! url: {project_url}')
    else:
        collected_data.append(data)

        print(f'Total: {len(collected_data)}')
        print()
# Out:
# 10001: https://www.zeczec.com/projects/travel-with-u
# ---- Start to collect travel-with-u ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect travel-with-u ----
# Total: 1
#
# 10002: https://www.zeczec.com/projects/shi-nong-hui-ben-chu-ban-ji-hua
# ---- Start to collect shi-nong-hui-ben-chu-ban-ji-hua ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect shi-nong-hui-ben-chu-ban-ji-hua ----
# Total: 2
#
# 10003: https://www.zeczec.com/projects/ht-chen
# ---- Start to collect ht-chen ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect ht-chen ----
# Total: 3
#
# 10004: https://www.zeczec.com/projects/ezplug
# ---- Start to collect ezplug ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect ezplug ----
# Total: 4
#
# 10005: https://www.zeczec.com/projects/sustain-heated-vest
# ---- Start to collect sustain-heated-vest ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect sustain-heated-vest ----
# Total: 5
#
# 10006: https://www.zeczec.com/projects/ausblick
# ---- Start to collect ausblick ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect ausblick ----
# Total: 6
#
# 10007: https://www.zeczec.com/projects/daypac
# ---- Start to collect daypac ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect daypac ----
# Total: 7
#
# 10008: https://www.zeczec.com/projects/vo-viginti-octo
# ---- Start to collect vo-viginti-octo ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect vo-viginti-octo ----
# Total: 8
#
# 10009: https://www.zeczec.com/projects/scenevanished
# ---- Start to collect scenevanished ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect scenevanished ----
# Total: 9
#
# 10010: https://www.zeczec.com/projects/doyouhearme
# ---- Start to collect doyouhearme ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect doyouhearme ----
# Total: 10
#
# 10011: https://www.zeczec.com/projects/urbanwallet
# ---- Start to collect urbanwallet ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect urbanwallet ----
# Total: 11
#
# 10012: https://www.zeczec.com/projects/staggekg600
# ---- Start to collect staggekg600 ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect staggekg600 ----
# Total: 12
#
# 10013: https://www.zeczec.com/projects/travel-with-u
# ---- Start to collect travel-with-u ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect travel-with-u ----
# Total: 13
#
# 10014: https://www.zeczec.com/projects/shi-nong-hui-ben-chu-ban-ji-hua
# ---- Start to collect shi-nong-hui-ben-chu-ban-ji-hua ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect shi-nong-hui-ben-chu-ban-ji-hua ----
# Total: 14
#
# 10015: https://www.zeczec.com/projects/ht-chen
# ---- Start to collect ht-chen ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect ht-chen ----
# Total: 15
#
# 10016: https://www.zeczec.com/projects/ezplug
# ---- Start to collect ezplug ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect ezplug ----
# Total: 16
#
# 10017: https://www.zeczec.com/projects/sustain-heated-vest
# ---- Start to collect sustain-heated-vest ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect sustain-heated-vest ----
# Total: 17
#
# 10018: https://www.zeczec.com/projects/ausblick
# ---- Start to collect ausblick ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect ausblick ----
# Total: 18
#
# 10019: https://www.zeczec.com/projects/daypac
# ---- Start to collect daypac ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect daypac ----
# Total: 19
#
# 10020: https://www.zeczec.com/projects/vo-viginti-octo
# ---- Start to collect vo-viginti-octo ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect vo-viginti-octo ----
# Total: 20
#
# 10021: https://www.zeczec.com/projects/scenevanished
# ---- Start to collect scenevanished ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect scenevanished ----
# Total: 21
#
# 10022: https://www.zeczec.com/projects/doyouhearme
# ---- Start to collect doyouhearme ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect doyouhearme ----
# Total: 22
#
# 10023: https://www.zeczec.com/projects/urbanwallet
# ---- Start to collect urbanwallet ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect urbanwallet ----
# Total: 23
#
# 10024: https://www.zeczec.com/projects/staggekg600
# ---- Start to collect staggekg600 ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect staggekg600 ----
# Total: 24
#
# 10025: https://www.zeczec.com/projects/travel-with-u
# ---- Start to collect travel-with-u ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect travel-with-u ----
# Total: 25
#
# 10026: https://www.zeczec.com/projects/shi-nong-hui-ben-chu-ban-ji-hua
# ---- Start to collect shi-nong-hui-ben-chu-ban-ji-hua ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect shi-nong-hui-ben-chu-ban-ji-hua ----
# Total: 26
#
# 10027: https://www.zeczec.com/projects/ht-chen
# ---- Start to collect ht-chen ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect ht-chen ----
# Total: 27
#
# 10028: https://www.zeczec.com/projects/ezplug
# ---- Start to collect ezplug ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect ezplug ----
# Total: 28
#
# 10029: https://www.zeczec.com/projects/sustain-heated-vest
# ---- Start to collect sustain-heated-vest ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect sustain-heated-vest ----
# Total: 29
#
# 10030: https://www.zeczec.com/projects/ausblick
# ---- Start to collect ausblick ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect ausblick ----
# Total: 30
#
# 10031: https://www.zeczec.com/projects/daypac
# ---- Start to collect daypac ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect daypac ----
# Total: 31
#
# 10032: https://www.zeczec.com/projects/vo-viginti-octo
# ---- Start to collect vo-viginti-octo ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect vo-viginti-octo ----
# Total: 32
#
# 10033: https://www.zeczec.com/projects/scenevanished
# ---- Start to collect scenevanished ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect scenevanished ----
# Total: 33
#
# 10034: https://www.zeczec.com/projects/doyouhearme
# ---- Start to collect doyouhearme ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect doyouhearme ----
# Total: 34
#
# 10035: https://www.zeczec.com/projects/urbanwallet
# ---- Start to collect urbanwallet ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect urbanwallet ----
# Total:
https://www.zeczec.com/projects/travel-with-u
# ---- Start to collect travel-with-u ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect travel-with-u ----
# Total: 169
#
# 10170: https://www.zeczec.com/projects/shi-nong-hui-ben-chu-ban-ji-hua
# ---- Start to collect shi-nong-hui-ben-chu-ban-ji-hua ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect shi-nong-hui-ben-chu-ban-ji-hua ----
# Total: 170
#
# 10171: https://www.zeczec.com/projects/ht-chen
# ---- Start to collect ht-chen ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect ht-chen ----
# Total: 171
#
# 10172: https://www.zeczec.com/projects/ezplug
# ---- Start to collect ezplug ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect ezplug ----
# Total: 172
#
# 10173: https://www.zeczec.com/projects/sustain-heated-vest
# ---- Start to collect sustain-heated-vest ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect sustain-heated-vest ----
# Total: 173
#
# 10174: https://www.zeczec.com/projects/ausblick
# ---- Start to collect ausblick ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect ausblick ----
# Total: 174
#
# 10175: https://www.zeczec.com/projects/daypac
# ---- Start to collect daypac ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect daypac ----
# Total: 175
#
# 10176: https://www.zeczec.com/projects/vo-viginti-octo
# ---- Start to collect vo-viginti-octo ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect vo-viginti-octo ----
# Total: 176
#
# 10177: https://www.zeczec.com/projects/scenevanished
# ---- Start to collect scenevanished ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect scenevanished ----
# Total: 177
#
# 10178: https://www.zeczec.com/projects/doyouhearme
# ---- Start to collect doyouhearme ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect doyouhearme ----
# Total: 178
#
# 10179: https://www.zeczec.com/projects/urbanwallet
# ---- Start to collect urbanwallet ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect urbanwallet ----
# Total: 179
#
# 10180: https://www.zeczec.com/projects/staggekg600
# ---- Start to collect staggekg600 ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect staggekg600 ----
# Total: 180
#
# 10181: https://www.zeczec.com/projects/travel-with-u
# ---- Start to collect travel-with-u ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect travel-with-u ----
# Total: 181
#
# 10182: https://www.zeczec.com/projects/shi-nong-hui-ben-chu-ban-ji-hua
# ---- Start to collect shi-nong-hui-ben-chu-ban-ji-hua ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect shi-nong-hui-ben-chu-ban-ji-hua ----
# Total: 182
#
# 10183: https://www.zeczec.com/projects/ht-chen
# ---- Start to collect ht-chen ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect ht-chen ----
# Total: 183
#
# 10184: https://www.zeczec.com/projects/ezplug
# ---- Start to collect ezplug ----
# collected [basic info]
# collected [project content]
# ...
# ---- Complete to collect ht-chen ----
# Total: 938
#
# 10940: https://www.zeczec.com/projects/ezplug
# ---- Start to collect ezplug ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect ezplug ----
# Total: 939
#
# 10941: https://www.zeczec.com/projects/sustain-heated-vest
# ---- Start to collect sustain-heated-vest ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect sustain-heated-vest ----
# Total: 940
#
# 10942: https://www.zeczec.com/projects/ausblick
# ---- Start to collect ausblick ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect ausblick ----
# Total: 941
#
# 10943: https://www.zeczec.com/projects/daypac
# ---- Start to collect daypac ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect daypac ----
# Total: 942
#
# 10944: https://www.zeczec.com/projects/vo-viginti-octo
# ---- Start to collect vo-viginti-octo ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect vo-viginti-octo ----
# Total: 943
#
# 10945: https://www.zeczec.com/projects/scenevanished
# ---- Start to collect scenevanished ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect scenevanished ----
# Total: 944
#
# 10946: https://www.zeczec.com/projects/doyouhearme
# ---- Start to collect doyouhearme ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect doyouhearme ----
# Total: 945
#
# 10947: https://www.zeczec.com/projects/urbanwallet
# ---- Start to collect urbanwallet ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect urbanwallet ----
# Total: 946
#
# 10948: https://www.zeczec.com/projects/staggekg600
# ---- Start to collect staggekg600 ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect staggekg600 ----
# Total: 947
#
# 10949: https://www.zeczec.com/projects/travel-with-u
# ---- Start to collect travel-with-u ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect travel-with-u ----
# Total: 948
#
# 10950: https://www.zeczec.com/projects/shi-nong-hui-ben-chu-ban-ji-hua
# ---- Start to collect shi-nong-hui-ben-chu-ban-ji-hua ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect shi-nong-hui-ben-chu-ban-ji-hua ----
# Total: 949
#
# 10951: https://www.zeczec.com/projects/ht-chen
# ---- Start to collect ht-chen ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect ht-chen ----
# Total: 950
#
# 10952: https://www.zeczec.com/projects/ezplug
# ---- Start to collect ezplug ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect ezplug ----
# Total: 951
#
# 10953: https://www.zeczec.com/projects/sustain-heated-vest
# ---- Start to collect sustain-heated-vest ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect sustain-heated-vest ----
# Total: 952
#
# 10954: https://www.zeczec.com/projects/ausblick
# ---- Start to collect ausblick ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect ausblick ----
# Total: 953
#
# 10955: https://www.zeczec.com/projects/daypac
# ---- Start to collect daypac ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect daypac ----
# Total: 954
#
# 10956: https://www.zeczec.com/projects/vo-viginti-octo
# ---- Start to collect vo-viginti-octo ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect vo-viginti-octo ----
# Total: 955
#
# 10957: https://www.zeczec.com/projects/scenevanished
# ---- Start to collect scenevanished ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect scenevanished ----
# Total: 956
#
# 10958: https://www.zeczec.com/projects/doyouhearme
# ---- Start to collect doyouhearme ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect doyouhearme ----
# Total: 957
#
# 10959: https://www.zeczec.com/projects/urbanwallet
# ---- Start to collect urbanwallet ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect urbanwallet ----
# Total: 958
#
# 10960: https://www.zeczec.com/projects/staggekg600
# ---- Start to collect staggekg600 ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect staggekg600 ----
# Total: 959
#
# 10961: https://www.zeczec.com/projects/travel-with-u
# ---- Start to collect travel-with-u ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect travel-with-u ----
# Total: 960
#
# 10962: https://www.zeczec.com/projects/shi-nong-hui-ben-chu-ban-ji-hua
# ---- Start to collect shi-nong-hui-ben-chu-ban-ji-hua ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect shi-nong-hui-ben-chu-ban-ji-hua ----
# Total: 961
#
# 10963: https://www.zeczec.com/projects/ht-chen
# ---- Start to collect ht-chen ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect ht-chen ----
# Total: 962
#
# 10964: https://www.zeczec.com/projects/ezplug
# ---- Start to collect ezplug ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect ezplug ----
# Total: 963
#
# 10965: https://www.zeczec.com/projects/sustain-heated-vest
# ---- Start to collect sustain-heated-vest ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect sustain-heated-vest ----
# Total: 964
#
# 10966: https://www.zeczec.com/projects/ausblick
# ---- Start to collect ausblick ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect ausblick ----
# Total: 965
#
# 10967: https://www.zeczec.com/projects/daypac
# ---- Start to collect daypac ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect daypac ----
# Total: 966
#
# 10968: https://www.zeczec.com/projects/vo-viginti-octo
# ---- Start to collect vo-viginti-octo ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect vo-viginti-octo ----
# Total: 967
#
# 10969: https://www.zeczec.com/projects/scenevanished
# ---- Start to collect scenevanished ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect scenevanished ----
# Total: 968
#
# 10970: https://www.zeczec.com/projects/doyouhearme
# ---- Start to collect doyouhearme ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect doyouhearme ----
# Total: 969
#
# 10971: https://www.zeczec.com/projects/urbanwallet
# ---- Start to collect urbanwallet ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect urbanwallet ----
# Total: 970
#
# 10972: https://www.zeczec.com/projects/staggekg600
# ---- Start to collect staggekg600 ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect staggekg600 ----
# Total: 971
#
# 10973: https://www.zeczec.com/projects/travel-with-u
# ---- Start to collect travel-with-u ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect travel-with-u ----
# Total: 972
#
# 10974: https://www.zeczec.com/projects/shi-nong-hui-ben-chu-ban-ji-hua
# ---- Start to collect shi-nong-hui-ben-chu-ban-ji-hua ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect shi-nong-hui-ben-chu-ban-ji-hua ----
# Total: 973
#
# 10975: https://www.zeczec.com/projects/ht-chen
# ---- Start to collect ht-chen ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect ht-chen ----
# Total: 974
#
# 10976: https://www.zeczec.com/projects/ezplug
# ---- Start to collect ezplug ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect ezplug ----
# Total: 975
#
# 10977: https://www.zeczec.com/projects/sustain-heated-vest
# ---- Start to collect sustain-heated-vest ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect sustain-heated-vest ----
# Total: 976
#
# 10978: https://www.zeczec.com/projects/ausblick
# ---- Start to collect ausblick ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect ausblick ----
# Total: 977
#
# 10979: https://www.zeczec.com/projects/daypac
# ---- Start to collect daypac ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect daypac ----
# Total: 978
#
# 10980: https://www.zeczec.com/projects/vo-viginti-octo
# ---- Start to collect vo-viginti-octo ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect vo-viginti-octo ----
# Total: 979
#
# 10981: https://www.zeczec.com/projects/scenevanished
# ---- Start to collect scenevanished ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect scenevanished ----
# Total: 980
#
# 10982: https://www.zeczec.com/projects/doyouhearme
# ---- Start to collect doyouhearme ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect doyouhearme ----
# Total: 981
#
# 10983: https://www.zeczec.com/projects/urbanwallet
# ---- Start to collect urbanwallet ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect urbanwallet ----
# Total: 982
#
# 10984: https://www.zeczec.com/projects/staggekg600
# ---- Start to collect staggekg600 ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect staggekg600 ----
# Total: 983
#
# 10985: https://www.zeczec.com/projects/travel-with-u
# ---- Start to collect travel-with-u ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect travel-with-u ----
# Total: 984
#
# 10986: https://www.zeczec.com/projects/shi-nong-hui-ben-chu-ban-ji-hua
# ---- Start to collect shi-nong-hui-ben-chu-ban-ji-hua ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect shi-nong-hui-ben-chu-ban-ji-hua ----
# Total: 985
#
# 10987: https://www.zeczec.com/projects/ht-chen
# ---- Start to collect ht-chen ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect ht-chen ----
# Total: 986
#
# 10988: https://www.zeczec.com/projects/ezplug
# ---- Start to collect ezplug ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect ezplug ----
# Total: 987
#
# 10989: https://www.zeczec.com/projects/sustain-heated-vest
# ---- Start to collect sustain-heated-vest ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect sustain-heated-vest ----
# Total: 988
#
# 10990: https://www.zeczec.com/projects/ausblick
# ---- Start to collect ausblick ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect ausblick ----
# Total: 989
#
# 10991: https://www.zeczec.com/projects/daypac
# ---- Start to collect daypac ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect daypac ----
# Total: 990
#
# 10992: https://www.zeczec.com/projects/vo-viginti-octo
# ---- Start to collect vo-viginti-octo ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect vo-viginti-octo ----
# Total: 991
#
# 10993: https://www.zeczec.com/projects/scenevanished
# ---- Start to collect scenevanished ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect scenevanished ----
# Total: 992
#
# 10994: https://www.zeczec.com/projects/doyouhearme
# ---- Start to collect doyouhearme ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect doyouhearme ----
# Total: 993
#
# 10995: https://www.zeczec.com/projects/urbanwallet
# ---- Start to collect urbanwallet ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect urbanwallet ----
# Total: 994
#
# 10996: https://www.zeczec.com/projects/staggekg600
# ---- Start to collect staggekg600 ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect staggekg600 ----
# Total: 995
#
# 10997: https://www.zeczec.com/projects/travel-with-u
# ---- Start to collect travel-with-u ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect travel-with-u ----
# Total: 996
#
# 10998: https://www.zeczec.com/projects/shi-nong-hui-ben-chu-ban-ji-hua
# ---- Start to collect shi-nong-hui-ben-chu-ban-ji-hua ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect shi-nong-hui-ben-chu-ban-ji-hua ----
# Total: 997
#
# 10999: https://www.zeczec.com/projects/ht-chen
# ---- Start to collect ht-chen ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect ht-chen ----
# Total: 998
#
# 11000: https://www.zeczec.com/projects/ezplug
# ---- Start to collect ezplug ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect ezplug ----
# Total: 999

# %%
## --- Save --- ##

pd.DataFrame(collected_data).to_csv(f'{file_name}.csv', index=False)

# %% [markdown]
# #### Test

# %%
data = zeczec_crawler('https://www.zeczec.com/projects/scion-36')
data
# Out:
# ---- Start to collect scion-36 ----
# collected [basic info]
# collected [project content]
# collected [project highlight content]
# collected [project img]
# ---- Complete to collect scion-36 ----
# {'id': 'scion-36',
#  'title': '【 i wash 薄型洗碗機 】 專為台灣住宅環境設計！超薄型Ｘ大容量Ｘ免安裝',
#  'category': '科技',
#  'duration': '2023/11/07 12:00 – 2023/12/06 02:00',
#  'desc': '台灣屋小人多，讓洗碗機因「空間和容量不足」無法普及，面對講求便利性的特殊住宅環境，i wash 薄型洗碗機正式誕生！台灣首款 6 人份大容量洗碗機，前所未見 36cm 超薄厚度，輕鬆容納 46 件餐具，而且「不需安裝」，買回家就能開洗！',
#  'text': '洗碗，那是過去的事。\n和家人在餐桌上享受豐盛的美食，是忙碌生活中彼此分享、連結的重要時光，而「洗碗」這項繁瑣的家務，消磨著這些日常喜悅。\ni wash 薄型洗碗機是讓你的家更像家的現代智慧，只要一個按鈕，清潔自動一次到位。不用再浪費時間站在水槽前、不用再擔心骯髒的碗盤山，省下大把時間，專注在美食和家人身上。\n在台灣，洗衣機的普及率已經幾乎來到 100%，但為何洗碗機卻遲遲無法普及呢？深入調查台灣家庭的使用需求，Scion 團隊發現以下這些困擾是讓許多人對洗碗機卻步的幾大關卡。\n\n\n\n\n在廚房，空間跟時間一樣重要。\n台灣的廚房其實沒有像國外那麽好的空間條件，可以安裝嵌入式洗碗機，而市面上許多桌上型洗碗機，即使體積不大，也會因為難以忽視的厚度，無法安置於狹小的廚房檯面。\n\n而 i wash 徹底改變了洗碗機的結構，打造出僅 36 公分的超薄機身，因為夠薄，所以不再受到空間限制，想放哪就放哪，成為小廚房的理想選擇，同時為大型廚房提供更多儲存空間，徹底解決台灣家庭安裝洗碗機的最大痛點。\n\n「買了洗碗機才發現：容量不夠，好難用...」\n這是許多人在入手洗碗機後才發現的惡夢，因為錯估了洗碗機的容量，還有自己的生活方式，導致洗碗機買了卻不常用，只能放著生灰塵。\n\n其實，市面上許多洗碗機雖然主打「四人份」，但其實放入兩人份的碗盤、餐具，空間早已所剩無幾，甚至無法放進烹飪用的廚具...。Scion 團隊知道：消費者需要的是更有延展空間的洗碗機，而「家庭人數 x 1.5 倍 合理且實際的容量！」\n據統計，台灣每三個家庭就有一個擁有超過 4 位家庭成員，三餐使用的碗盤餐具、再加上廚具，要洗的東西超多！更別說偶爾還想約朋友來家裡吃火鍋...。\n\n除非是獨居、沒有訪客，否則「四人份」的擺放容量，其實並不實際，分兩次洗？反而造成流程的不順！當 Scion 團隊透過創新結構把洗碗機變薄了，容量卻不減反增，創造出的六人份的大容量，能彈性應付所有生活情境，清潔一次到位。\n\n想像一下：打開洗碗機，乾燥清爽的香氣撲鼻而來～\n台灣的氣候潮濕又悶熱，碗盤洗完若沒有立即弄乾，總是會有股悶悶的臭味，而市面上大多數的洗碗機只有「餘溫烘乾」的功能，洗完要馬上拿出來，不然容易產生「反潮、發霉、水垢」等難以解決的惡夢，讓碗怎麼洗，都是臭的 🤢\n\n針對台灣的潮濕環境研發，i wash 薄型洗碗機成為市面唯一具有「獨立烘乾」功能的大容量薄型洗碗機！不只在每次清洗完畢後，會自動開啟 60 分鐘的烘乾時間，讓碗盤快速恢復乾燥。平時也能獨立當作「烘碗機」使用，確保每次打開，就能享受清爽乾淨的餐盤！\n\n是洗碗機、烘碗機、還是碗盤收納櫃！\n不只如此，i wash 薄型洗碗機在洗程結束後，會進入「自動通風」模式，每 90 分鐘會進行一次 15 分鐘的間歇換氣，並持續 72 小時，保持空氣流通，確保碗盤不會潮濕悶臭，也能避免洗碗機底部產生難以清潔的水垢與黴菌。\n在待機時，面板會即時顯示當下溫度，不洗碗時也能直接拿來收納碗盤，完全不浪費空間！\n\n忘掉惱人的管線問題及複雜的安裝！考量到大多數高齡房屋及租屋族的困境，i wash 薄型洗碗機提供了「雙進水」兩種彈性選擇，水線可接、可不接，從此不需要改管線、鑽孔，也不用與專業師傅預約安裝。\n\n洗碗機帶回家就可以直接開洗！即使搬家，插頭一拔，也能立即帶走，是最有彈性的洗碗機首選。\n\n輕食或油膩碗盤都 ok！超乎想像的清潔能力\ni wash 薄型洗碗機具有 5 種清洗模式，不管是油膩的平底鍋、頑固的食物殘渣還是玻璃器皿，都能以最高 75°C 熱水漂洗、再搭配強力水柱沖洗，提供超越想像的清潔效果，只要按下按鍵，最快 28 分鐘就能讓碗盤清潔溜溜，每一次使用都是驚喜的體驗！\n\ni wash 薄型洗碗機除了在機器上方有一支噴水臂，下方還有兩支，一共 22 道 3D 立體水柱，比起大部分只在下方設有一支噴水臂的洗碗機，提供更強勁的沖洗力道、360° 均勻清潔零死角，確保每一個碗盤和餐具都經歷無與倫比的清潔過程。不僅能去除食物殘渣，更能輕鬆處理最難洗的污漬，讓餐具閃閃發亮，就像新的一樣 ✨\n\n\n\n\n最後是許多家中長輩擔心的「浪費水」問題，實測手洗 6 人份的餐具，約需花費 15 分鐘，若在水龍頭保持開啟的狀況下，手洗餐具 15 分鐘會用掉將近 135L 的水量，相當驚人 💦\n\n而 i wash 薄型洗碗機每次清洗花費的水量僅有 5.2L，只需花費手洗不到 1/25 的水量，每次可以省下 216 個寶特瓶的水，是比手洗更省水、更乾淨、更輕鬆的選擇！\n\n在每次洗程結束之後，i wash 薄型洗碗機會在洗程的最後 10 分鐘自動開啟 UV 紫外線殺菌燈，深層抑菌、徹底消滅看不見的髒東西，寶寶的奶瓶和奶嘴也能安心清潔！\n\n\n\n更有效的智能時間管理，晚餐後將碗盤放入，預約洗程，等補習完的孩子吃宵夜，再放入餐具，時間一到自動開始清潔，不用擔心睡前忘記按開關，起床就有乾乾淨淨的碗盤可以用，開啟全新的一天！\n\n\n\n\n\ni wash 薄型洗碗機提供一整年的免費到府安心保固，且在全台灣都有保固服務中心，方便就近解決使用上的各種疑難雜症，讓消費者買得更安心！\n\n\n\n風險與挑戰\n・ i wash 薄型洗碗機 集資達標後，就會立即進入量產階段，產品將於 2023 年 12 月底 依照訂單順序出貨，謝謝您的支持與耐心等待。後續進度將持續發佈於「嘖嘖集資－專案更新」與「i wash 薄型洗碗機」FB粉絲專頁。\n\n・ 產品顏色可能因螢幕呈現而有些許差異，實際顏色以實品為主。\n・ 使用本產品前請詳閱使用說明，使用本產品即視為您已詳閱免責聲明與警告信息，且理解、接受內容所提及的全部條款。\n・ 募資計畫有諸多變數，團隊以準時完成生產、出貨為宗旨，但仍有意外事件發生的可能（如工廠延宕、物流延宕等）導致出貨延期。贊助此計畫，即視為你已同意承擔此風險，若無法接受延遲出貨風險，請於「募資結束前」聯繫嘖嘖客服 support@zeczec.com 信箱取消贊助。\n退換貨規則\n・根據法令規定消費者有權享有商品審閱期，鑑賞（審閱）期非試用期，因商品屬性不同，本商品無開放試用體驗，洗碗機商品一但拆箱定位、落地安裝、開機使用後，非商品瑕疵不良或故障因素，皆不接受退（換）貨。商品經安裝或使用後如需拆卸，將酌收 1800 元之退貨處理費。\n・鑑賞期 / 猶豫期非試用期，退回時應確保商品包裝及內容之完整性，包含所有配件、贈品等所附文件一併退回，並切勿使用、缺漏任何配件或損毀原外盒。\n・一年硬體到府維修保固自拆封（安裝）日起，開始計算。\n・若屬於下列任一情況者，產品則屬於「非保固範圍」：\n1. 商品無訂購單號或機號與實物不符合者。\n2. 因消費者未按使用手冊或說明書規定，使用不當而毀損者，包括重壓、摔壞、受潮、浸水、淋雨、異物侵入、遺失零組件等所造成之損壞。\n3. 因正常使用時，所造成產品外殼或不需拆解而可接觸部分上之刮傷、磨損。\n4. 使用非原廠配件或不適配的裝置導致產品的損壞。\n5. 因天災或不可抗拒之外力而造成產品損壞者。\n6. 未經由本公司授權之人員拆卸或維修，或自行拆裝、改裝產品、任意變更規格。\n7. 無法提出證明購自嘖嘖的來源不明商品。\n客服聯絡方式\n如對產品有任何疑問，歡迎點選頁面的「聯絡提案人」與我們聯絡；或是私訊「i wash 薄型洗碗機」的 FB 粉絲專頁：https://www.facebook.com/scion.dishwasher ，我們將盡快回覆您。\nEmail 請聯繫 scionlimitedco@gmail.com（私訊 FB 粉專會比較快回覆哦！）\n營業人登記資訊\n營業人名稱：匯盛國際行銷有限公司\n統一編號：24358865\n對計畫還有其他疑問嗎？請見常見問答。\n認為此專案有違規或不適合嘖嘖使用者的地方嗎？請填寫表單協助我們檢查。',
#  'color_text': ['i wash 薄型洗碗機是讓你的家更像家的現代智慧，只要一個按鈕，清潔自動一次到位。',
#   '深入調查台灣家庭的使用需求，Scion 團隊發現以下這些困擾是讓許多人對洗碗機卻步的幾大關卡。',
#   '徹底',
#   '改變了洗碗機的結構，打造出僅 36 公分的超薄機身，因為夠薄，所以不再受到空間限制，想放哪就放哪，',
#   '錯估了洗碗機的容量',
#   '消費者需要的是更有延展空間的洗碗機，而「家庭人數 x 1.5 倍 合理且實際的容量！」',
#   '台灣每三個家庭就有一個擁有超過 4 位家庭成員',
#   '把洗碗機變薄了，容量卻不減反增，創造出的六人份的大容量',
#   '大多數的洗碗機只有「餘溫烘乾」的功能',
#   '不然容易產生「反潮、發霉、水垢」等難以解決的惡夢',
#   '市面唯一具有「獨立烘乾」功能的大容量薄型洗碗機',
#   '獨立當作「烘碗機」使用',
#   '「自動通風」模式，每 90 分鐘會進行一次 15 分鐘的間歇換氣，並持續 72 小時，保持空氣流通',
#   '不洗碗時也能直接拿來收納碗盤',
#   '「雙進水」兩種彈性選擇，水線可接、可不接',
#   '即使搬家，插頭一拔，也能立即帶走',
#   '5 種清洗模式',
#   '最高 75°C 熱水漂洗',
#   '再搭配強力水柱沖洗',
#   '上方有一支噴水臂，下方還有兩支，一共 22 道 3D 立體水柱',
#   '提供更強勁的沖洗力道、360° 均勻清潔零死角',
#   '💦\n\n而 i wash 薄型洗碗機每次清洗花費的水量僅有 5.2L，只需花費手洗不到 1/25 的水量，每次可以省下 216 個寶特瓶的水',
#   '寶寶的奶瓶和奶嘴也能安心清潔',
#   '不用擔心睡前忘記按開關，起床就有乾乾淨淨的碗盤可以用',
#   '一整年的免費到府安心保固'],
#  'bold_text': [],
#  'hyper_text': [],
#  'img_list': ['https://assets.zeczec.com/asset_724638_image_big.jpg?1699431248',
#   'http://i.countdownmail.com/2vwpd3.gif',
#   'https://assets.zeczec.com/asset_722921_image_big.jpg?1699113591',
#   'https://assets.zeczec.com/asset_715275_image_big.jpg?1698106771',
#   'https://assets.zeczec.com/asset_720362_image_big.jpg?1698752304',
#   'https://assets.zeczec.com/asset_720378_image_big.gif?1698753754',
#   'https://assets.zeczec.com/asset_723969_image_big.jpg?1699337714',
#   'https://assets.zeczec.com/asset_722521_image_big.jpg?1699001128',
#   'https://assets.zeczec.com/asset_722359_image_big.jpg?1698991019',
#   'https://assets.zeczec.com/asset_723562_image_big.jpg?1699265007',
#   'https://assets.zeczec.com/asset_723564_image_big.jpg?1699265022',
#   'https://assets.zeczec.com/asset_723565_image_big.jpg?1699265035',
#   'https://assets.zeczec.com/asset_723566_image_big.jpg?1699265048',
#   'https://assets.zeczec.com/asset_723567_image_big.jpg?1699265059',
#   'https://assets.zeczec.com/asset_723629_image_big.jpg?1699271181',
#   'https://assets.zeczec.com/asset_720373_image_big.jpg?1698753253',
#   'https://assets.zeczec.com/asset_720492_image_big.gif?1698762348',
#   'https://assets.zeczec.com/asset_721621_image_big.jpg?1698900361',
#   'https://assets.zeczec.com/asset_720400_image_big.jpg?1698755385',
#   'https://assets.zeczec.com/asset_720399_image_big.jpg?1698755355',
#   'https://assets.zeczec.com/asset_721443_image_big.jpg?1698893357',
#   'https://assets.zeczec.com/asset_722642_image_big.jpg?1699007391',
